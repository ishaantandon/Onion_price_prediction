# %%
import pandas as pd
import openmeteo_requests
import requests_cache
from retry_requests import retry
import time
import os

# 1. Setup API client
cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)

def fetch_historical_weather(lat, lon):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
        "latitude": lat, "longitude": lon,
        "start_date": "2018-01-01", "end_date": "2024-12-31",
        "daily": ["temperature_2m_mean", "relative_humidity_2m_mean", "precipitation_sum"],
        "timezone": "auto"
    }
    try:
        # Added a timeout of 60 seconds to prevent the "7-minute hang"
        responses = openmeteo.weather_api(url, params=params)
        response = responses[0]
        daily = response.Daily()
        return pd.DataFrame({
            "date": pd.date_range(
                start=pd.to_datetime(daily.Time(), unit="s"),
                periods=len(daily.Variables(0).ValuesAsNumpy()),
                freq='D'
            ),
            "temp": daily.Variables(0).ValuesAsNumpy(),
            "humidity": daily.Variables(1).ValuesAsNumpy(),
            "rain": daily.Variables(2).ValuesAsNumpy(),
            "latitude": lat,
            "longitude": lon
        })
    except Exception as e:
        if "limit exceeded" in str(e).lower() or "timeout" in str(e).lower():
            print(f"Connection issue/Rate limit. Waiting 60s and retrying...")
            time.sleep(60)
            return fetch_historical_weather(lat, lon)
        print(f"Skipping {lat}, {lon} due to error: {e}")
        return None

# 2. Load Data
csv_path = r"C:\Users\PESU-RF\Downloads\Onions\Onions\processed_data\lat_long\mandi_coordinates.csv"
df_locations = pd.read_csv(csv_path).dropna(subset=['latitude', 'longitude'])
output_filename = "historical_weather_2018_2024.parquet"

# 3. Execution Loop with Checkpointing
for index, row in df_locations.iterrows():
    print(f"[{index + 1}/{len(df_locations)}] Fetching: {row['latitude']}, {row['longitude']}")
    
    # Check if this location is already in our saved file (optional resume logic)
    # For now, we will just append each new location.
    
    df_result = fetch_historical_weather(row['latitude'], row['longitude'])
    
    if df_result is not None:
        # SAVE IMMEDIATELY: This keeps data safe even if the script hangs later
        if not os.path.exists(output_filename):
            df_result.to_parquet(output_filename, engine='fastparquet', index=False)
        else:
            df_result.to_parquet(output_filename, engine='fastparquet', append=True, index=False)
    
    time.sleep(1.5) # Slightly faster but still safe

print(f"Success! Process complete. Data is in {output_filename}")
# Out:
# [1/1113] Fetching: 27.1308555, 93.709712
# [2/1113] Fetching: 26.4249628, 90.9712027
# [3/1113] Fetching: 26.0865358, 89.964662
# [4/1113] Fetching: 27.4844597, 94.9019447
# [6/1113] Fetching: 26.4449658, 92.5268228
# [7/1113] Fetching: 15.590853, 73.8102146
# [11/1113] Fetching: 21.7718836, 72.1416449
# [12/1113] Fetching: 21.0943917, 71.7568456
# [14/1113] Fetching: 22.4732415, 70.0552102
# [15/1113] Fetching: 21.3417058, 70.7534299
# [18/1113] Fetching: 22.8003959, 70.886232
# [19/1113] Fetching: 21.9575096, 70.8009896
# [21/1113] Fetching: 21.1923647, 72.9551023
# [89/1113] Fetching: 16.0547194, 76.9003647
# [90/1113] Fetching: 13.3400771, 77.1006208
# [91/1113] Fetching: 9.3182808, 76.6085318
# [92/1113] Fetching: 9.2931789, 76.4146872
# [93/1113] Fetching: 9.1723603, 76.500061
# [94/1113] Fetching: 10.1077682, 76.3568532
# [95/1113] Fetching: 10.1910284, 76.3874109
# [96/1113] Fetching: 9.9837257, 76.2740001
# [97/1113] Fetching: 10.1147548, 76.4778152
# [98/1113] Fetching: 9.9440256, 76.3489858
# [99/1113] Fetching: 10.0869959, 77.0600915
# [100/1113] Fetching: 9.8976798, 76.7134225
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Skipping 9.8976798, 76.7134225 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.8976798&longitude=76.7134225&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [101/1113] Fetching: 9.5729206, 77.0918879
# Skipping 9.5729206, 77.0918879 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.5729206&longitude=77.0918879&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [102/1113] Fetching: 11.8763836, 75.3737973
# Skipping 11.8763836, 75.3737973 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=11.8763836&longitude=75.3737973&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [104/1113] Fetching: 8.8870815, 76.5907017
# Skipping 8.8870815, 76.5907017 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=8.8870815&longitude=76.5907017&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [105/1113] Fetching: 9.0055368, 76.7832172
# Skipping 9.0055368, 76.7832172 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.0055368&longitude=76.7832172&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [106/1113] Fetching: 9.6678442, 76.5328609
# Skipping 9.6678442, 76.5328609 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.6678442&longitude=76.5328609&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [107/1113] Fetching: 9.6751487, 76.5460114
# Skipping 9.6751487, 76.5460114 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.6751487&longitude=76.5460114&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [108/1113] Fetching: 9.5440324, 76.8104166
# Skipping 9.5440324, 76.8104166 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.5440324&longitude=76.8104166&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [109/1113] Fetching: 9.6287383, 76.6455326
# Skipping 9.6287383, 76.6455326 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.6287383&longitude=76.6455326&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [110/1113] Fetching: 9.7401938, 76.5175417
# Skipping 9.7401938, 76.5175417 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.7401938&longitude=76.5175417&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [111/1113] Fetching: 20.8331539, 77.7047967
# Skipping 20.8331539, 77.7047967 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=20.8331539&longitude=77.7047967&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [112/1113] Fetching: 9.5656334, 76.6443645
# Skipping 9.5656334, 76.6443645 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=9.5656334&longitude=76.6443645&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [113/1113] Fetching: 11.6836738, 75.6645224
# Skipping 11.6836738, 75.6645224 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=11.6836738&longitude=75.6645224&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [114/1113] Fetching: 8.822364, 76.6462584
# Skipping 8.822364, 76.6462584 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=8.822364&longitude=76.6462584&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [115/1113] Fetching: 8.5030538, 76.9500997
# Skipping 8.5030538, 76.9500997 due to error: failed to request 'https://archive-api.open-meteo.com/v1/archive': HTTPSConnectionPool(host='archive-api.open-meteo.com', port=443): Max retries exceeded with url: /v1/archive?latitude=8.5030538&longitude=76.9500997&start_date=2018-01-01&end_date=2024-12-31&daily=temperature_2m_mean&daily=relative_humidity_2m_mean&daily=precipitation_sum&timezone=auto&format=flatbuffers (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1028)')))
# [116/1113] Fetching: 11.559725, 75.7581231
# Connection issue/Rate limit. Waiting 60s and retrying...
# [117/1113] Fetching: 11.4183747, 76.0190597
# [118/1113] Fetching: 11.1457203, 75.9643753
# [119/1113] Fetching: 11.0004806, 76.004758
# [120/1113] Fetching: 11.1202289, 76.1198109
# [121/1113] Fetching: 11.0507863, 75.8640002
# [123/1113] Fetching: 10.7873691, 76.4742172
# [124/1113] Fetching: 10.8048616, 76.1780161
# [125/1113] Fetching: 10.5922019, 76.4840809
# [126/1113] Fetching: 10.5243344, 76.0799391
# [127/1113] Fetching: 10.3815259, 76.1748018
# [128/1113] Fetching: 10.2269615, 76.1984049
# Connection issue/Rate limit. Waiting 60s and retrying...
# [129/1113] Fetching: 10.6027705, 76.2025814
# [130/1113] Fetching: 8.4830928, 76.952177
# [135/1113] Fetching: 23.8716706, 76.7744703
# [137/1113] Fetching: 22.9778614, 75.8466312
# [138/1113] Fetching: 22.8869652, 74.7243249
# [140/1113] Fetching: 24.2628148, 75.385692
# [141/1113] Fetching: 23.3054063, 74.7715584
# [142/1113] Fetching: 24.6305517, 75.1829
# [143/1113] Fetching: 23.4559437, 74.9273527
# [145/1113] Fetching: 19.1627725, 74.8580243
# [148/1113] Fetching: 19.3797171, 75.2954872
# Connection issue/Rate limit. Waiting 60s and retrying...
# [153/1113] Fetching: 21.1305215, 74.4900614
# [154/1113] Fetching: 16.7028412, 74.2405329
# [155/1113] Fetching: 19.0594069, 72.9602962
# [156/1113] Fetching: 21.1498134, 79.0820556
# [157/1113] Fetching: 19.9468174, 79.2553995
# [160/1113] Fetching: 20.1426837, 74.2377507
# [161/1113] Fetching: 20.1426837, 74.2377507
# [162/1113] Fetching: 20.5576062, 74.5246514
# [163/1113] Fetching: 20.2519828, 74.4392286
# [164/1113] Fetching: 19.9834939, 73.8926931
# [165/1113] Fetching: 20.7016928, 77.7187997
# [167/1113] Fetching: 20.5991006, 74.2021078
# [168/1113] Fetching: 19.8972539, 74.1623127
# [169/1113] Fetching: 20.0429079, 74.4880389
# [170/1113] Fetching: 18.1125305, 74.9238654
# [171/1113] Fetching: 18.5213738, 73.8545071
# [173/1113] Fetching: 17.271977, 74.5372841
# [174/1113] Fetching: 17.2852127, 74.1822147
# [175/1113] Fetching: 18.0387975, 74.186926
# [176/1113] Fetching: 20.4801154, 78.1676841
# [178/1113] Fetching: 17.8499067, 75.2763203
# [179/1113] Fetching: 28.7070448, 77.1803722
# [180/1113] Fetching: 24.6953682, 78.2090834
# [181/1113] Fetching: 28.6758661, 77.2985078
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...
# Connection issue/Rate limit. Waiting 60s and retrying...

# %%
# %pip install openmeteo_requests requests_cache retry_requests fastparquet
# Out:
# Requirement already satisfied: openmeteo_requests in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (1.7.4)
# Requirement already satisfied: requests_cache in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Requirement already satisfied: retry_requests in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (2.0.0)
# Collecting fastparquet
#   Downloading fastparquet-2025.12.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: niquests>=3.15.2 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from openmeteo_requests) (3.16.1)
# Requirement already satisfied: openmeteo-sdk>=1.22.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from openmeteo_requests) (1.23.0)
# Requirement already satisfied: attrs>=21.2 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests_cache) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests_cache) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from requests_cache) (4.4.0)
# Requirement already satisfied: requests>=2.22 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests_cache) (2.32.5)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests_cache) (2.2.1)
# Requirement already satisfied: urllib3>=1.25.5 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests_cache) (2.6.2)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from fastparquet) (2.3.3)
# Requirement already satisfied: numpy in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from fastparquet) (2.3.3)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl.metadata (681 bytes)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from fastparquet) (25.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from cattrs>=22.2->requests_cache) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from niquests>=3.15.2->openmeteo_requests) (3.4.4)
# Requirement already satisfied: urllib3-future<3,>=2.13.903 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from niquests>=3.15.2->openmeteo_requests) (2.15.901)
# Requirement already satisfied: wassima<3,>=1.0.1 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from niquests>=3.15.2->openmeteo_requests) (2.0.3)
# Requirement already satisfied: h11<1.0.0,>=0.11.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (0.16.0)
# Requirement already satisfied: jh2<6.0.0,>=5.0.3 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (5.0.10)
# Requirement already satisfied: qh3<2.0.0,>=1.5.4 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from urllib3-future<3,>=2.13.903->niquests>=3.15.2->openmeteo_requests) (1.5.6)
# Requirement already satisfied: flatbuffers==25.9.23 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from openmeteo-sdk>=1.22.0->openmeteo_requests) (25.9.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.22->requests_cache) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.22->requests_cache) (2025.11.12)
# Downloading fastparquet-2025.12.0-cp313-cp313-win_amd64.whl (667 kB)
#    ---------------------------------------- 0.0/667.4 kB ? eta -:--:--
#    --------------------------------------- 667.4/667.4 kB 20.9 MB/s eta 0:00:00
# Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 28.4 MB/s eta 0:00:00
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Installing collected packages: fsspec, cramjam, fastparquet
#
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    -------------------------- ------------- 2/3 [fastparquet]
#    ---------------------------------------- 3/3 [fastparquet]
#
# Successfully installed cramjam-2.11.0 fastparquet-2025.12.0 fsspec-2025.12.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
