# %%
import pandas as pd
import glob
import os

# Folder paths
input_folder = r"C:\Users\PESU-RF\Downloads\Onions\Onions\raw_data(1)"
output_folder = r"C:\Users\PESU-RF\Downloads\Onions\Onions"
os.makedirs(output_folder, exist_ok=True)
output_file = os.path.join(output_folder, "raw_master_dataset_all_varieties.parquet")

# Get all .xls files
files = glob.glob(os.path.join(input_folder, "*.xls"))

all_dfs = []

for file in files:
    try:
        # 1. Attempt to read as HTML (for the 'pseudo-xls' files)
        tables = pd.read_html(file)
        if tables:
            df = tables[0]
            all_dfs.append(df)
            print(f"✅ Loaded (HTML format): {os.path.basename(file)}")
            
    except (UnicodeDecodeError, ValueError):
        # 2. Fallback: Read as a standard Excel file if HTML parsing fails
        try:
            # We skip the first row here because Agmarknet binary files 
            # often have the same 'Both Price And Arrival...' header at index 0
            df = pd.read_excel(file, skiprows=1)
            all_dfs.append(df)
            print(f"📘 Loaded (Standard Excel format): {os.path.basename(file)}")
        except Exception as e:
            print(f"❌ Failed to load {os.path.basename(file)}: {e}")
            
    except Exception as e:
        print(f"❌ Unexpected error in {os.path.basename(file)}: {e}")

# Merge and process
if all_dfs:
    merged_df = pd.concat(all_dfs, ignore_index=True)

    # Clean column names (strips whitespace and handles potential multi-index headers)
    merged_df.columns = [str(c).strip() for c in merged_df.columns]

    # Agmarknet often uses 'Arrival Date' instead of 'date'
    # Checking for common date column names
    date_col = next((c for c in merged_df.columns if "date" in c.lower()), None)
    if date_col:
        merged_df[date_col] = pd.to_datetime(merged_df[date_col], errors='coerce')

    # Sort and Clean
    # Using 'Market Name' as per your shared screenshot
    sort_cols = [c for c in [date_col, "Market Name"] if c is not None and c in merged_df.columns]
    if sort_cols:
        merged_df.sort_values(by=sort_cols, inplace=True)
    
    merged_df.reset_index(drop=True, inplace=True)

    # Save as Parquet
    merged_df.to_parquet(output_file, index=False)
    print(f"\n🎉 Master dataset saved to: {output_file}")
    print(f"Total rows processed: {len(merged_df)}")
else:
    print("No data found to merge.")
# Out:
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (1).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (10).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (11).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (12).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (13).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (14).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (15).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (16).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (17).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (18).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (19).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (2).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (20).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (21).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (22).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (23).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (24).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (25).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (26).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (27).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (28).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (29).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (3).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (30).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (31).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (32).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (33).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (34).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (35).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (36).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (37).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (38).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (39).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (4).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (40).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (41).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (42).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (43).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (44).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (45).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (46).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (47).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (48).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (49).xls
# 📘 Loaded (Standard Excel format): Agmarknet_Price_And_Arrival_Report (5).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (50).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (51).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (52).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (53).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (54).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (55).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (56).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (57).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (58).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (59).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (6).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (60).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (61).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (62).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (63).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (64).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (65).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (7).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (8).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report (9).xls
# ✅ Loaded (HTML format): Agmarknet_Price_And_Arrival_Report.xls
# ✅ Loaded (HTML format): apr2018.xls
# ✅ Loaded (HTML format): aug2018.xls
# ✅ Loaded (HTML format): dec2018.xls
# ✅ Loaded (HTML format): feb2018.xls
# ✅ Loaded (HTML format): jan2018.xls
# ✅ Loaded (HTML format): jul2018.xls
# ✅ Loaded (HTML format): jun2018.xls
# ✅ Loaded (HTML format): mar2018.xls
# ✅ Loaded (HTML format): may2018.xls
# ✅ Loaded (HTML format): nov2018.xls
# ✅ Loaded (HTML format): oct2018.xls
# ✅ Loaded (HTML format): sep2018.xls
#
# 🎉 Master dataset saved to: C:\Users\PESU-RF\Downloads\Onions\Onions\raw_master_dataset_all_varieties.parquet
# Total rows processed: 1296271

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.15.0)
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#
#    -------------------- ------------------- 1/2 [beautifulsoup4]
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pesu-rf\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pesu-rf\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# FIND TOTAL NUMBER OF ROWS IN ALL THE SEPERATE XLS FILES

import pandas as pd
import glob
import os

# Define the folder path
input_folder = r"C:\Users\PESU-RF\Downloads\Onions\Onions\raw_data(1)"

# Get all .xls files
files = glob.glob(os.path.join(input_folder, "*.xls"))

total_rows = 0
file_count = 0

print(f"Starting row count for {len(files)} files...\n")

for file in files:
    try:
        # 1. Try reading as HTML
        tables = pd.read_html(file)
        if tables:
            df = tables[0]
            current_rows = len(df)
            total_rows += current_rows
            file_count += 1
            print(f"Counted: {os.path.basename(file)} -> {current_rows} rows")
            
    except (UnicodeDecodeError, ValueError):
        # 2. Fallback: Try reading as standard binary Excel
        try:
            # skiprows=1 to match your cleaning logic
            df = pd.read_excel(file, skiprows=1)
            current_rows = len(df)
            total_rows += current_rows
            file_count += 1
            print(f"Counted (Binary): {os.path.basename(file)} -> {current_rows} rows")
        except Exception as e:
            print(f"❌ Failed to read {os.path.basename(file)}: {e}")
            
    except Exception as e:
        print(f"❌ Unexpected error in {os.path.basename(file)}: {e}")

print("-" * 30)
print(f"📊 Summary Statistics:")
print(f"Total Files Processed: {file_count}")
print(f"Total Combined Rows: {total_rows}")
print("-" * 30)
# Out:
# Starting row count for 78 files...
#
# Counted: Agmarknet_Price_And_Arrival_Report (1).xls -> 14492 rows
# Counted: Agmarknet_Price_And_Arrival_Report (10).xls -> 11087 rows
# Counted: Agmarknet_Price_And_Arrival_Report (11).xls -> 3530 rows
# Counted: Agmarknet_Price_And_Arrival_Report (12).xls -> 13856 rows
# Counted: Agmarknet_Price_And_Arrival_Report (13).xls -> 12793 rows
# Counted: Agmarknet_Price_And_Arrival_Report (14).xls -> 11553 rows
# Counted: Agmarknet_Price_And_Arrival_Report (15).xls -> 11255 rows
# Counted: Agmarknet_Price_And_Arrival_Report (16).xls -> 12822 rows
# Counted: Agmarknet_Price_And_Arrival_Report (17).xls -> 13484 rows
# Counted: Agmarknet_Price_And_Arrival_Report (18).xls -> 13335 rows
# Counted: Agmarknet_Price_And_Arrival_Report (19).xls -> 12421 rows
# Counted: Agmarknet_Price_And_Arrival_Report (2).xls -> 15904 rows
# Counted: Agmarknet_Price_And_Arrival_Report (20).xls -> 12961 rows
# Counted: Agmarknet_Price_And_Arrival_Report (21).xls -> 12318 rows
# Counted: Agmarknet_Price_And_Arrival_Report (22).xls -> 12434 rows
# Counted: Agmarknet_Price_And_Arrival_Report (23).xls -> 14427 rows
# Counted: Agmarknet_Price_And_Arrival_Report (24).xls -> 27411 rows
# Counted: Agmarknet_Price_And_Arrival_Report (25).xls -> 28298 rows
# Counted: Agmarknet_Price_And_Arrival_Report (26).xls -> 26148 rows
# Counted: Agmarknet_Price_And_Arrival_Report (27).xls -> 28219 rows
# Counted: Agmarknet_Price_And_Arrival_Report (28).xls -> 28162 rows
# Counted: Agmarknet_Price_And_Arrival_Report (29).xls -> 28888 rows
# Counted: Agmarknet_Price_And_Arrival_Report (3).xls -> 15329 rows
# Counted: Agmarknet_Price_And_Arrival_Report (30).xls -> 16208 rows
# Counted: Agmarknet_Price_And_Arrival_Report (31).xls -> 15728 rows
# Counted: Agmarknet_Price_And_Arrival_Report (32).xls -> 17690 rows
# Counted: Agmarknet_Price_And_Arrival_Report (33).xls -> 17433 rows
# Counted: Agmarknet_Price_And_Arrival_Report (34).xls -> 16904 rows
# Counted: Agmarknet_Price_And_Arrival_Report (35).xls -> 16741 rows
# Counted: Agmarknet_Price_And_Arrival_Report (36).xls -> 16830 rows
# Counted: Agmarknet_Price_And_Arrival_Report (37).xls -> 16616 rows
# Counted: Agmarknet_Price_And_Arrival_Report (38).xls -> 16479 rows
# Counted: Agmarknet_Price_And_Arrival_Report (39).xls -> 15632 rows
# Counted: Agmarknet_Price_And_Arrival_Report (4).xls -> 15892 rows
# Counted: Agmarknet_Price_And_Arrival_Report (40).xls -> 16440 rows
# Counted: Agmarknet_Price_And_Arrival_Report (41).xls -> 17231 rows
# Counted: Agmarknet_Price_And_Arrival_Report (42).xls -> 16684 rows
# Counted: Agmarknet_Price_And_Arrival_Report (43).xls -> 15907 rows
# Counted: Agmarknet_Price_And_Arrival_Report (44).xls -> 16228 rows
# Counted: Agmarknet_Price_And_Arrival_Report (45).xls -> 15979 rows
# Counted: Agmarknet_Price_And_Arrival_Report (46).xls -> 16876 rows
# Counted: Agmarknet_Price_And_Arrival_Report (47).xls -> 16877 rows
# Counted: Agmarknet_Price_And_Arrival_Report (48).xls -> 16885 rows
# Counted: Agmarknet_Price_And_Arrival_Report (49).xls -> 16549 rows
# Counted (Binary): Agmarknet_Price_And_Arrival_Report (5).xls -> 30545 rows
# Counted: Agmarknet_Price_And_Arrival_Report (50).xls -> 15984 rows
# Counted: Agmarknet_Price_And_Arrival_Report (51).xls -> 16168 rows
# Counted: Agmarknet_Price_And_Arrival_Report (52).xls -> 14941 rows
# Counted: Agmarknet_Price_And_Arrival_Report (53).xls -> 16147 rows
# Counted: Agmarknet_Price_And_Arrival_Report (54).xls -> 15814 rows
# Counted: Agmarknet_Price_And_Arrival_Report (55).xls -> 15432 rows
# Counted: Agmarknet_Price_And_Arrival_Report (56).xls -> 15712 rows
# Counted: Agmarknet_Price_And_Arrival_Report (57).xls -> 14549 rows
# Counted: Agmarknet_Price_And_Arrival_Report (58).xls -> 17493 rows
# Counted: Agmarknet_Price_And_Arrival_Report (59).xls -> 17426 rows
# Counted: Agmarknet_Price_And_Arrival_Report (6).xls -> 15889 rows
# Counted: Agmarknet_Price_And_Arrival_Report (60).xls -> 21742 rows
# Counted: Agmarknet_Price_And_Arrival_Report (61).xls -> 21567 rows
# Counted: Agmarknet_Price_And_Arrival_Report (62).xls -> 21410 rows
# Counted: Agmarknet_Price_And_Arrival_Report (63).xls -> 21614 rows
# Counted: Agmarknet_Price_And_Arrival_Report (64).xls -> 20383 rows
# Counted: Agmarknet_Price_And_Arrival_Report (65).xls -> 21712 rows
# Counted: Agmarknet_Price_And_Arrival_Report (7).xls -> 15026 rows
# Counted: Agmarknet_Price_And_Arrival_Report (8).xls -> 13912 rows
# Counted: Agmarknet_Price_And_Arrival_Report (9).xls -> 13695 rows
# Counted: Agmarknet_Price_And_Arrival_Report.xls -> 15889 rows
# Counted: apr2018.xls -> 13443 rows
# Counted: aug2018.xls -> 14502 rows
# Counted: dec2018.xls -> 15874 rows
# Counted: feb2018.xls -> 13375 rows
# Counted: jan2018.xls -> 14353 rows
# Counted: jul2018.xls -> 14487 rows
# Counted: jun2018.xls -> 13988 rows
# Counted: mar2018.xls -> 14550 rows
# Counted: may2018.xls -> 15504 rows
# Counted: nov2018.xls -> 14115 rows
# Counted: oct2018.xls -> 15315 rows
# Counted: sep2018.xls -> 14779 rows
# ------------------------------
# 📊 Summary Statistics:
# Total Files Processed: 78
# Total Combined Rows: 1296271
# ------------------------------

# %%
# FIND ALL DIFF VALS IN COLS "VARIETY", "GROUP", "GRADE". THEN FIND THE NUMBER OF RECORDS OF EACH DIFF VAL IN ITS COL RESPECTIVELY

import pandas as pd

# ===============================
# LOAD PARQUET FILE
# ===============================
# Change this path to your actual parquet file
FILE_PATH = r"C:\Users\PESU-RF\Downloads\Onions\Onions\raw_master_dataset_all_varieties.parquet"

df = pd.read_parquet(FILE_PATH)

# ===============================
# 1) VARIETY COUNTS
# ===============================
print("\n===============================")
print("VARIETY – UNIQUE VALUES & COUNTS")
print("===============================")

variety_counts = df["Variety"].value_counts(dropna=False)
print(variety_counts)

# ===============================
# 2) GROUP COUNTS
# ===============================
print("\n===============================")
print("GROUP – UNIQUE VALUES & COUNTS")
print("===============================")

group_counts = df["Group"].value_counts(dropna=False)
print(group_counts)

# ===============================
# 3) GRADE COUNTS
# ===============================
print("\n===============================")
print("GRADE – UNIQUE VALUES & COUNTS")
print("===============================")

grade_counts = df["Grade"].value_counts(dropna=False)
print(grade_counts)

# ===============================
# OPTIONAL: SAVE RESULTS
# ===============================
summary = {
    "Variety": variety_counts,
    "Group": group_counts,
    "Grade": grade_counts
}

summary_df = pd.concat(summary, axis=1)
summary_df.to_csv("unique_counts_variety_group_grade.csv")

print("\nSaved summary to: unique_counts_variety_group_grade.csv")
# Out:
# ===============================
# VARIETY – UNIQUE VALUES & COUNTS
# ===============================
# Variety
# Other               459013
# Red                 351844
# Onion               163586
# 1st Sort             58912
# Nasik                50182
# Big                  45281
# Local                43061
# None                 30545
# Bellary              29706
# Small                20959
# Medium               12885
# White                 6865
# Pusa-Red              4776
# Puna                  3545
# Dry F.A.Q.            3018
# Bombay (U.P.)         3016
# Beelary-Red           2141
# 2nd Sort              1888
# Telagi                1511
# Pole                  1504
# Hybrid                1155
# Bangalore-Samall       647
# Onion-Organic          226
# Small - I                4
# New Pune                 1
# Name: count, dtype: int64
#
# ===============================
# GROUP – UNIQUE VALUES & COUNTS
# ===============================
# Group
# Vegetables    1265726
# None            30545
# Name: count, dtype: int64
#
# ===============================
# GRADE – UNIQUE VALUES & COUNTS
# ===============================
# Grade
# FAQ       1233882
# None        30545
# Local       29769
# Medium       1719
# Large         333
# Small          23
# Name: count, dtype: int64
#
# Saved summary to: unique_counts_variety_group_grade.csv
